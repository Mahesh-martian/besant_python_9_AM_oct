# %% [markdown]
# ## polymorphism

# %% [markdown]
# ### Method overloading

# %%
class Calculator:

    def add(self,a,b):
        print(a+b)

    def add(self,a,b,c):
        print(a+b+c)

    def add(self,a,b,c,d):
        print(a+b+c+d)

calc = Calculator()
calc.add(10,20,30,40)  # This will call the last defined add method
# Out:
# 100

# %% [markdown]
# ### Method overriding

# %%
class Parent:
    def car(self):
        print("maruthi 800")

    def land(self):
        print("doing agriculture")

class child(Parent):
    def mobile(self):
        print("I phone")

    def land(self):
        print("appartment")

    def car(self):
        print("modified maruthi 800")

c1 = child()
c1.mobile()
c1.land()
c1.car()
# Out:
# I phone
# appartment
# modified maruthi 800

# %% [markdown]
# ### operator overloading

# %%
class book:

    def __init__(self, name, price):
        self.name = name
        self.price = price

    def __str__(self):
        return self.name
    
    def __add__(self,other):
        return self.price + other.price
    
b1 = book('harry potter', 1000)
b2 = book('Rich dad poor dad', 450)
print(b1+b2)
print(b1)
# Out:
# 1450
# harry potter
